# %%
from keras.datasets import imdb
(train_data, train_labels),(test_data,test_labels) = imdb.load_data(num_words= 10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
train_data[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
train_labels[0]
# Out:
# np.int64(1)

# %%
print(type([max(sequence) for sequence in train_data]))
max([max(sequence) for sequence in train_data])
# Out:
# <class 'list'>
# 9999

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
word_index = imdb.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_review = ' '.join([reverse_word_index.get(i-3, '?') for i in train_data[0]])
decoded_review
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# "? this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert ? is an amazing actor and now the same being director ? father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for ? and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also ? to the two little boy's that played the ? of norman and paul they were just brilliant children are often left out of the ? list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %%
len(reverse_word_index)
# Out:
# 88584

# %%
import numpy as np
def vectorize_sequences(sequences, dimension = 10000):
    results = np.zeros((len(sequences),dimension))
    for i,sequence in enumerate(sequences):
        results[i,sequence] = 1
    return results

xtrain = vectorize_sequences(train_data)
xtest = vectorize_sequences(test_data)

# %%
xtrain[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
xtrain.shape
# Out:
# (25000, 10000)

# %%
ytrain = np.asarray(train_labels).astype('float32')
ytest = np.asarray(test_labels).astype('float32')

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape = (10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from keras import optimizers
from keras import losses
from keras import metrics

model.compile(optimizer= optimizers.RMSprop(learning_rate= 0.001),
              loss = losses.binary_crossentropy,
              metrics= [metrics.binary_accuracy])

# %%
xval = xtrain[:10000]
partial_xtrain = xtrain[10000:]

yval = ytrain[:10000]
partial_ytrain = ytrain[10000:]

# %%
history = model.fit(partial_xtrain,
                    partial_ytrain,
                    epochs=20,
                    batch_size= 512,
                    validation_data=(xval, yval))
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - binary_accuracy: 0.7795 - loss: 0.5148 - val_binary_accuracy: 0.8647 - val_loss: 0.3911
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - binary_accuracy: 0.9009 - loss: 0.3138 - val_binary_accuracy: 0.8687 - val_loss: 0.3319
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - binary_accuracy: 0.9197 - loss: 0.2378 - val_binary_accuracy: 0.8870 - val_loss: 0.2848
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - binary_accuracy: 0.9355 - loss: 0.1924 - val_binary_accuracy: 0.8891 - val_loss: 0.2745
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - binary_accuracy: 0.9468 - loss: 0.1605 - val_binary_accuracy: 0.8834 - val_loss: 0.2926
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - binary_accuracy: 0.9559 - loss: 0.1362 - val_binary_accuracy: 0.8851 - val_loss: 0.2890
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - binary_accuracy: 0.9619 - loss: 0.1192 - val_binary_accuracy: 0.8837 - val_loss: 0.2979
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - binary_accuracy: 0.9724 - loss: 0.1003 - val_binary_accuracy: 0.8849 - val_loss: 0.3126
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - binary_accuracy: 0.9742 - loss: 0.0882 - val_binary_accuracy: 0.8805 - val_loss: 0.3288
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - binary_accuracy: 0.9793 - loss: 0.0738 - val_binary_accuracy: 0.8761 - val_loss: 0.3505
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - binary_accuracy: 0.9822 - loss: 0.0658 - val_binary_accuracy: 0.8772 - val_loss: 0.3670
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - binary_accuracy: 0.9869 - loss: 0.0536 - val_binary_accuracy: 0.8750 - val_loss: 0.4110
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - binary_accuracy: 0.9896 - loss: 0.0472 - val_binary_accuracy: 0.8768 - val_loss: 0.4182
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - binary_accuracy: 0.9916 - loss: 0.0405 - val_binary_accuracy: 0.8740 - val_loss: 0.4399
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - binary_accuracy: 0.9914 - loss: 0.0375 - val_binary_accuracy: 0.8706 - val_loss: 0.4810
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - binary_accuracy: 0.9953 - loss: 0.0276 - val_binary_accuracy: 0.8719 - val_loss: 0.4804
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - binary_accuracy: 0.9964 - loss: 0.0246 - val_binary_accuracy: 0.8612 - val_loss: 0.5364
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - binary_accuracy: 0.9952 - loss: 0.0240 - val_binary_accuracy: 0.8610 - val_loss: 0.6083
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - binary_accuracy: 0.9987 - loss: 0.0159 - val_binary_accuracy: 0.8683 - val_loss: 0.5457
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - binary_accuracy: 0.9958 - loss: 0.0202 - val_binary_accuracy: 0.8683 - val_loss: 0.5625

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['binary_accuracy', 'loss', 'val_binary_accuracy', 'val_loss'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values)+1)

plt.plot(epochs, loss_values, 'bo', label = "Training Loss")
plt.plot(epochs, val_loss_values, 'b', label = "Validation Loss")

plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss Value')
plt.legend()

plt.show()

# %%
acc_values = history_dict['binary_accuracy']
val_acc_values = history_dict['val_binary_accuracy']

epochs = range(1, len(loss_values)+1)

plt.plot(epochs, acc_values, 'ro', label = "Training Accuracy")
plt.plot(epochs, val_acc_values, 'r', label = "Validation Accuracy")

plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
model.fit(partial_xtrain,
          partial_ytrain,
          epochs= 3,
          batch_size= 512,
          validation_data=(xval,yval))
# Out:
# Epoch 1/3
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - binary_accuracy: 0.9967 - loss: 0.0176 - val_binary_accuracy: 0.8689 - val_loss: 0.5834
# Epoch 2/3
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - binary_accuracy: 0.9997 - loss: 0.0087 - val_binary_accuracy: 0.8688 - val_loss: 0.6010
# Epoch 3/3
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - binary_accuracy: 0.9973 - loss: 0.0135 - val_binary_accuracy: 0.8696 - val_loss: 0.6227

# %%
np.set_printoptions(suppress= True)
result = model.predict(xtest)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
result
# Out:
# array([[0.01928216],
#        [0.9999999 ],
#        [0.8871794 ],
#        ...,
#        [0.00207303],
#        [0.00328068],
#        [0.9856498 ]], dtype=float32)

# %%
y_pred = np.zeros(len(result))
for i, score in enumerate(result):
    y_pred[i] = 1 if score > 0.5 else 0

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_pred, ytest)

# %%
mae
# Out:
# 0.14268
